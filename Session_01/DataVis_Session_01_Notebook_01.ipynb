# %%
# generate Python 3.12 environment with conda
#!conda create -n datavis python=3.12
#!pip install gapminder

# %%
import pandas as pd
import numpy as np

from gapminder import gapminder

from matplotlib import pyplot as plt
from matplotlib.lines import Line2D

from sklearn.preprocessing import minmax_scale

# %%
gapminder.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
colors = {'Africa':'tab:brown', 'Asia':'tab:red', 'Europe':'tab:grey', 'Americas':'tab:green', 'Oceania':'tab:blue'}
handles = [Line2D([0], [0], marker='o', color='w', markerfacecolor=v, label=k, markersize=8) for k, v in colors.items()]

fig = plt.figure(figsize=(10, 6))
ax = plt.subplot()
ax.scatter(gapminder["gdpPercap"], gapminder["lifeExp"], s=minmax_scale(gapminder["pop"], (10,1000)), c=gapminder["continent"].map(colors), alpha=0.5)
ax.set_xlabel("GDP per capita")
ax.set_ylabel("Life expectancy")
ax.legend(title='Continents', handles=handles, bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
gapminder_europe = gapminder[gapminder["continent"] == "Europe"]
gapminder_asia = gapminder[gapminder["continent"] == "Asia"]

# %%
fig, ax = plt.subplots(2,1, figsize=(10, 6), sharex=True, sharey=True)
ax[0].plot(gapminder_europe["gdpPercap"], gapminder_europe["lifeExp"], marker="o", linestyle="none")
ax[1].plot(gapminder_asia["gdpPercap"], gapminder_asia["lifeExp"], marker="o", linestyle="none")
ax[0].set_title("Europe")
ax[1].set_title("Asia")
ax[0].set_ylabel("Life expectancy")
ax[1].set_ylabel("Life expectancy")
ax[1].set_xlabel("GDP per capita")
plt.show()

# %%
plt.style.use('classic')

fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(gapminder_europe["gdpPercap"], gapminder_europe["lifeExp"], marker="o", linestyle="none")
ax.set_title("GPD vs. Life Expectancy in Europe")
ax.set_ylabel("Life expectancy")
ax.set_xlabel("GDP per capita")
plt.show()
